# %% [markdown]
# # 🌟 Gün 1 — Python'a İlk Adım ve Veriye Giriş
# ### STEAM Yaz Kampı 2026 • Veri Bilimi Günü
#
# Bugün iki şey yapacağız:
# 1. **Python'un temellerini** birlikte, bol alıştırmayla öğreneceğiz 🐍
# 2. Sonra bu becerilerle **gerçek bir veriyi** okuyup, filtreleyip grafiğe dökeceğiz 📊
#
# Hiç kod yazmadıysan hiç sorun değil — her şeyi adım adım, beraber yapacağız.
#
# ---
# ### 📌 Bu defter nasıl kullanılır?
# - Bir hücreyi çalıştırmak için içine tıkla, sonra **▶️ (oynat)** düğmesine bas veya **Shift + Enter**.
# - **Hücreleri yukarıdan aşağıya sırayla çalıştır.**
# - İşaretler:
#
# | İşaret | Anlamı |
# |--------|--------|
# | ✏️ | **Sen değiştir** — bu satırda bir şeyi kendin değiştirip tekrar çalıştır |
# | 🎯 | **Senin sıran** — küçük bir alıştırma |
# | 📝 | **Çalışma Kitapçığı** — çıkan sonucu kâğıttaki forma yaz |
# | 🧑‍🏫 | Öğretmen / cevap anahtarı |
# | 💡 | İpucu |
#
# > Hata almaktan korkma! Programcılar her gün hata alır; hata mesajını okumak işin bir parçasıdır. 😊

# %% [markdown]
# > 🤖 **Bu, defterin "çıktılı önizleme" sürümüdür.** Asıl çalışacağınız Colab defteri
# > [`notebooks/`](../notebooks) klasöründe. Buraya, normal hücrelerin **arasına**:
# > 🔧 *deneyebileceğiniz varyasyonlar* (çalıştırılmış hâlde), 📊 *sonuçların nasıl
# > yorumlanacağı* ve mini projelerde 🎤 *sunum rehberleri* eklendi. Bu eklemeler
# > **yeşil/gri kutularla** ayrılmıştır; siz de aynı şeyleri kendi defterinizde deneyebilirsiniz.

# %% [markdown]
# ---
# ## 0. Hazırlık — Önce Google Drive'ı bağla
# Koda başlamadan önce, dosyalarımıza erişmek için Google Drive'ı bağlayalım. Aşağıdaki hücreyi çalıştır; açılan pencerede **kendi Google hesabınla** giriş yap ve **izin ver**. `✅ Her şey hazır!` yazısını görünce hazırsın.
#
# 🧑‍🏫 *Öğretmen notu:* Klasör adı tam olarak `STEM_yaz_kampi_2026` olmalı. (Python alıştırmaları için Drive şart değil ama en baştan bağlamak en kolayı.)

# %%
# Bu hücreyi olduğu gibi çalıştır.

import os

from python_code.helper_tr import *     # hazır yardımcı fonksiyonlar
print('✅ Her şey hazır!')
# Out:
# ✅ Her şey hazır!

# %% [markdown]
# ---
# # 🐍 BÖLÜM A — Python Temelleri (Atölye)
# Önce kod yazmayı öğreniyoruz. Bu bölümde ~12 kısa konu var; her birinde önce örneği çalıştır, sonra 🎯 alıştırmayı dene.

# %% [markdown]
# ## A1. `print()` — Ekrana yazı yazmak
# Python'da bir şeyi ekranda görmek için `print()` kullanırız. `#` ile başlayan satırlar **yorum**dur; Python onları çalıştırmaz, sadece bizim için not.

# %%
# Bu bir yorum satırı — Python bunu çalıştırmaz.
print("Merhaba dünya!")
print("Python öğrenmek eğlenceli")
# Out:
# Merhaba dünya!
# Python öğrenmek eğlenceli

# %% [markdown]
# 🎯 **Senin sıran:** Aşağıya kendi mesajını yazıp çalıştır.

# %%
# ✏️ Tırnakların içine kendi cümleni yaz:
print("...")
# Out:
# ...

# %% [markdown]
# ## A2. Değişkenler — Bilgiyi bir "kutuda" saklamak
# Değişken, içine bir değer koyduğumuz isimli bir kutudur. Python'da 4 temel değer türü:
#
# | Tür | Ne demek | Örnek |
# |-----|----------|-------|
# | `str` (metin) | yazı — **tırnak** içinde | `"Malatya"` |
# | `int` (tam sayı) | tam sayı | `16` |
# | `float` (ondalık) | ondalıklı sayı | `1.75` |
# | `bool` (mantıksal) | Doğru/Yanlış | `True` / `False` |

# %%
ad = "Zeynep"        # str  (metin)
yas = 16             # int  (tam sayı)
boy = 1.68           # float (ondalık)
ogrenci_mi = True    # bool (doğru/yanlış)

print(ad, "•", yas, "yaşında •", boy, "m boyunda • öğrenci:", ogrenci_mi)
# Out:
# Zeynep • 16 yaşında • 1.68 m boyunda • öğrenci: True

# %% [markdown]
# 🎯 **Senin sıran:** Değerleri KENDİ bilgilerinle değiştir ve çalıştır.

# %%
# ✏️ Kendi bilgilerini yaz:
ad = "..."
yas = 0
sehir = "..."
print(ad, yas, "yaşında,", sehir, "şehrinden.")
# Out:
# ... 0 yaşında, ... şehrinden.

# %% [markdown]
# ## A3. Matematik işlemleri
# Python harika bir hesap makinesidir:
#
# | İşlem | Sembol | Örnek | Sonuç |
# |-------|--------|-------|-------|
# | Toplama | `+` | `5 + 3` | 8 |
# | Çıkarma | `-` | `5 - 3` | 2 |
# | Çarpma | `*` | `5 * 3` | 15 |
# | Bölme | `/` | `7 / 2` | 3.5 |
# | Tam bölme | `//` | `7 // 2` | 3 |
# | Kalan (mod) | `%` | `7 % 2` | 1 |
# | Üs alma | `**` | `2 ** 3` | 8 |

# %%
print("Toplama :", 5 + 3)
print("Bölme   :", 7 / 2)
print("Kalan   :", 7 % 2)
print("Üs alma :", 2 ** 10)   # 2 üzeri 10

# Değişkenlerle de hesap yapabiliriz:
yas = 16
gun_sayisi = yas * 365
print(ad if False else "Yaşın gün olarak (yaklaşık):", gun_sayisi)
# Out:
# Toplama : 8
# Bölme   : 3.5
# Kalan   : 1
# Üs alma : 1024
# Yaşın gün olarak (yaklaşık): 5840

# %% [markdown]
# 🎯 **Senin sıran:** Bir dikdörtgenin alanını hesapla.

# %%
# ✏️ en ve boy değerlerini değiştir:
en = 4
boy = 6
alan = en * boy
print("Dikdörtgenin alanı:", alan)
# Out:
# Dikdörtgenin alanı: 24

# %% [markdown]
# ## A4. `type()` ve tür dönüşümü
# `type()` bir değerin türünü söyler. Bazen türü değiştirmemiz gerekir: `int()`, `float()`, `str()`.

# %%
print(type("Malatya"))   # <class 'str'>
print(type(16))          # <class 'int'>
print(type(1.68))        # <class 'float'>

# Metni sayıya çevirmek:
metin_sayi = "25"
gercek_sayi = int(metin_sayi)
print(gercek_sayi + 5)   # artık toplayabiliriz -> 30
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 30

# %% [markdown]
# 💡 **Sık hata:** `"25" + 5` HATA verir (metin + sayı olmaz). Önce `int("25")` ile sayıya çevir. Bunu birazdan göreceğiz, korkma!

# %% [markdown]
# ## A5. Metinlerle (string) oynamak
# Metinler üzerinde birçok işlem yapabiliriz. En kullanışlısı **f-string**: bir metnin içine `{}` ile değişken koymak.

# %%
sehir = "Malatya"

print("Harf sayısı:", len(sehir))      # uzunluk
print("BÜYÜK harf :", sehir.upper())
print("küçük harf :", sehir.lower())
print("İlk harf   :", sehir[0])        # 0'dan sayarız!
print("İlk 3 harf :", sehir[0:3])      # dilimleme

# f-string: metnin içine değişken gömmek (çok kullanışlı!)
yas = 16
print(f"{sehir} şehrinden, {yas} yaşındayım.")
# Out:
# Harf sayısı: 7
# BÜYÜK harf : MALATYA
# küçük harf : malatya
# İlk harf   : M
# İlk 3 harf : Mal
# Malatya şehrinden, 16 yaşındayım.

# %% [markdown]
# 🎯 **Senin sıran:** Bir kelimeyi büyük harfe çevir ve harf sayısını yazdır.

# %%
# ✏️ kelime'yi değiştir:
kelime = "kayısı"
print(f"{kelime} kelimesinde {len(kelime)} harf var ve büyük hali {kelime.upper()}")
# Out:
# kayısı kelimesinde 6 harf var ve büyük hali KAYISI

# %% [markdown]
# ## A6. Kullanıcıdan bilgi almak — `input()`
# `input()`, kullanıcıdan yazı ister. Çalıştırınca hücrenin altında bir kutu çıkar; oraya yazıp **Enter**'a bas.
#
# 💡 `input()` her zaman **metin** döndürür. Sayı lazımsa `int(...)` ile çevir.
#
# ⚠️ *Bu hücre senden bir şey yazmanı bekler — yazana kadar bekler.*

# %%
isim = input("Adın ne? ")
print(f"Tanıştığıma memnun oldum, {isim}! 👋")
# Out:
# Adın ne? Zeynep
# Tanıştığıma memnun oldum, Zeynep! 👋

# %% [markdown]
# 🎯 **Senin sıran:** Doğum yılını sor ve yaşını hesapla.

# %%
dogum_yili = int(input("Doğduğun yıl: "))   # int(...) ile sayıya çevir
yas = 2026 - dogum_yili
print(f"2026'da {yas} yaşında oluyorsun.")
# Out:
# Doğduğun yıl: 2010
# 2026'da 16 yaşında oluyorsun.

# %% [markdown]
# ## A7. Listeler — birden çok bilgiyi bir arada tutmak
# Liste, köşeli parantez `[]` içinde birçok değeri tutar. **Sıralama 0'dan başlar!**

# %%
sehirler = ["Malatya", "İstanbul", "Ankara", "İzmir", "Trabzon"]

print("Listede", len(sehirler), "şehir var")
print("İlk şehir (0) :", sehirler[0])
print("Son şehir (-1):", sehirler[-1])
print("İlk üç        :", sehirler[0:3])

# Listeye yeni eleman ekleyelim:
sehirler.append("Gaziantep")
print("Eklemeden sonra:", sehirler)
# Out:
# Listede 5 şehir var
# İlk şehir (0) : Malatya
# Son şehir (-1): Trabzon
# İlk üç        : ['Malatya', 'İstanbul', 'Ankara']
# Eklemeden sonra: ['Malatya', 'İstanbul', 'Ankara', 'İzmir', 'Trabzon', 'Gaziantep']

# %% [markdown]
# 🎯 **Senin sıran:** En sevdiğin 5 yiyeceği bir listeye koy, 3. sıradakini yazdır (3. sıra = index `2`).

# %%
# ✏️ kendi yiyeceklerini yaz:
yiyecekler = ["...", "...", "...", "...", "..."]
print("3. sıradaki yiyecek:", yiyecekler[2])
# Out:
# 3. sıradaki yiyecek: ...

# %% [markdown]
# ## A8. Hazır fonksiyonlar — `len`, `sum`, `min`, `max`, `round`, `sorted`
# Python'da hazır gelen, çok işe yarayan fonksiyonlar:

# %%
notlar = [85, 90, 72, 60, 95, 88]

print("Kaç not  :", len(notlar))
print("Toplam   :", sum(notlar))
print("En düşük :", min(notlar))
print("En yüksek:", max(notlar))
print("Ortalama :", round(sum(notlar) / len(notlar), 1))   # round(sayı, basamak)
print("Sıralı   :", sorted(notlar))
# Out:
# Kaç not  : 6
# Toplam   : 490
# En düşük : 60
# En yüksek: 95
# Ortalama : 81.7
# Sıralı   : [60, 72, 85, 88, 90, 95]

# %% [markdown]
# 🎯 **Senin sıran:** Aşağıdaki sıcaklıkların ortalamasını ve en yükseğini bul.

# %%
# ✏️ istersen sayıları değiştir:
sicakliklar = [28, 31, 35, 33, 27]
print("Ortalama sıcaklık:", round(sum(sicakliklar) / len(sicakliklar), 1))
print("En sıcak gün     :", max(sicakliklar))
# Out:
# Ortalama sıcaklık: 30.8
# En sıcak gün     : 35

# %% [markdown]
# ## A9. Koşullar — `if` / `elif` / `else`
# Bilgisayara "eğer ... ise şunu yap, değilse bunu yap" dedirtiriz. Karşılaştırma sembolleri: `==` (eşit), `!=` (eşit değil), `<`, `>`, `<=`, `>=`.

# %%
not_ortalamasi = 78

if not_ortalamasi >= 85:
    print("Pekiyi 🌟")
elif not_ortalamasi >= 70:
    print("İyi 🙂")
else:
    print("Geliştirmen lazım 💪")
# Out:
# İyi 🙂

# %% [markdown]
# 💡 `and` (ve), `or` (veya), `not` (değil) ile koşulları birleştirebilirsin: `if yas >= 13 and yas <= 19:` → genç.
#
# 🎯 **Senin sıran:** Bir sayı pozitif mi, negatif mi, sıfır mı?

# %%
# ✏️ sayi'yı değiştir:
sayi = -4
if sayi > 0:
    print("Pozitif")
elif sayi < 0:
    print("Negatif")
else:
    print("Sıfır")
# Out:
# Negatif

# %% [markdown]
# ## A10. Döngüler — `for` ile tekrar tekrar
# Bir işi her eleman için tekrarlamak istediğimizde **döngü** kullanırız. `range(n)` 0'dan n-1'e kadar sayar.

# %%
# Bir listedeki her şehri tek tek yazdır:
sehirler = ["Malatya", "İstanbul", "İzmir"]
for sehir in sehirler:
    print("Şehir:", sehir)

print("---")

# range ile 1'den 5'e kadar:
for i in range(1, 6):
    print(i, "kere kare:", i ** 2)
# Out:
# Şehir: Malatya
# Şehir: İstanbul
# Şehir: İzmir
# ---
# 1 kere kare: 1
# 2 kere kare: 4
# 3 kere kare: 9
# 4 kere kare: 16
# 5 kere kare: 25

# %% [markdown]
# 🎯 **Senin sıran:** Bir döngüyle 1'den 10'a kadar olan sayıların toplamını bul.

# %%
toplam = 0
for sayi in range(1, 11):     # 1, 2, ..., 10
    toplam = toplam + sayi    # her adımda ekle
print("1'den 10'a kadar toplam:", toplam)
# Out:
# 1'den 10'a kadar toplam: 55

# %% [markdown]
# ## A11. Kendi fonksiyonunu yaz — `def`
# Bir işi bir kez tanımlayıp tekrar tekrar kullanmak için **fonksiyon** yazarız. `def` ile tanımlanır, `return` ile sonuç döndürür.

# %%
# selamla adında bir fonksiyon tanımlayalım:
def selamla(isim):
    return f"Merhaba {isim}, kampa hoş geldin! 🎉"

# Şimdi istediğimiz kadar kullanabiliriz:
print(selamla("Zeynep"))
print(selamla("Ahmet"))

# Sayı döndüren bir fonksiyon:
def kare_al(x):
    return x * x

print("5'in karesi:", kare_al(5))
# Out:
# Merhaba Zeynep, kampa hoş geldin! 🎉
# Merhaba Ahmet, kampa hoş geldin! 🎉
# 5'in karesi: 25

# %% [markdown]
# 🎯 **Senin sıran:** İki sayıyı toplayan bir fonksiyon yaz.

# %%
# ✏️ return satırını tamamla (a + b):
def topla(a, b):
    return a + b

print("3 + 7 =", topla(3, 7))
# Out:
# 3 + 7 = 10

# %% [markdown]
# ## A12. Sözlükler — `dict` (etiketli bilgi)
# Liste sırayla tutar; **sözlük** ise *anahtar → değer* şeklinde etiketli tutar. Süslü parantez `{}` kullanılır.

# %%
ogrenci = {
    "ad": "Zeynep",
    "yas": 16,
    "sehir": "Malatya"
}

print("Ad   :", ogrenci["ad"])
print("Şehir:", ogrenci["sehir"])

# Yeni bilgi ekleyelim:
ogrenci["okul"] = "Fen Lisesi"
print(ogrenci)
# Out:
# Ad   : Zeynep
# Şehir: Malatya
# {'ad': 'Zeynep', 'yas': 16, 'sehir': 'Malatya', 'okul': 'Fen Lisesi'}

# %% [markdown]
# ## 🏆 Mini Meydan Okuma — Öğrendiklerini birleştir!
# Aşağıda bazı illerin nüfusu var. Bir **döngü** ve bir **koşul** kullanarak nüfusu 1 milyondan büyük illeri yazdıralım. (Bu, birazdan yapacağımız veri analizinin "elle" hali!)

# %%
nufuslar = {"Malatya": 742725, "İstanbul": 15655924, "Bayburt": 81910, "İzmir": 4479525}

print("Nüfusu 1 milyondan büyük iller:")
for il in nufuslar:
    if nufuslar[il] > 1000000:
        print(" -", il, "→", nufuslar[il], "kişi")
# Out:
# Nüfusu 1 milyondan büyük iller:
#  - İstanbul → 15655924 kişi
#  - İzmir → 4479525 kişi

# %% [markdown]
# 🎉 **Tebrikler!** Artık değişken, liste, sözlük, koşul, döngü ve fonksiyon biliyorsun. Şimdi bunları **gerçek ve büyük** bir veride kullanacağız — ama elle değil, hazır araçlarla!

# %% [markdown]
# ---
# # 📊 BÖLÜM B — Gerçek Veriyle Çalışmak
# Artık Python öğrendin! 🎉 Aşağıdaki bölümler **Çalışma Kitapçığı'ndaki Gün 1 sayfalarını** takip eder.
#
# 💡 Drive'ı en başta (Bölüm 0) bağlamıştık, o yüzden doğrudan veriye geçebiliriz.

# %% [markdown]
# ---
# ## 1. Veri Setiyle Tanışma
# ### 📝 Çalışma Kitapçığı — Gün 1, Bölüm 1
#
# Türkiye'nin **81 ilinin demografi verisini** (TÜİK 2023) açacağız. Her il için: bölge, nüfus, doğurganlık oranı, ortalama yaş.
#
# 💡 Bu veri, A bölümündeki sözlüğe benzer ama **81 il × 5 bilgi** içeriyor. Elle döngü yazmak yerine **pandas** denen güçlü bir araç kullanacağız.

# %%
# Veriyi oku. Çıktıda ilk 5 satırı ve kaç satır/sütun olduğunu görürsün.
df = veri_yukle('input_data/iller_demografi.csv')
# Out:
# 📂 'input_data/iller_demografi.csv' okunuyor...
# ✅ Yüklendi: 81 satır × 5 sütun
#
# İlk 5 satır:
#          il       bolge     nufus  dogurganlik_orani  ortalama_yas
# 0  İstanbul     Marmara  15655924               1.49          33.5
# 1    Ankara  İç Anadolu   5803482               1.55          33.7
# 2     İzmir         Ege   4479525               1.39          36.2
# 3     Bursa     Marmara   3214571               1.62          33.8
# 4   Antalya     Akdeniz   2696249               1.59          34.4

# %% [markdown]
# Şimdi verinin **özetine** bakalım: kaç satır, kaç sütun, eksik (boş) değer var mı?

# %%
veriyi_ozetle(df)
# Out:
# 📊 Veri boyutu: 81 satır × 5 sütun
#
# Sütun tipleri:
# il                    object
# bolge                 object
# nufus                  int64
# dogurganlik_orani    float64
# ortalama_yas         float64
# dtype: object
#
# Eksik değer sayısı (sütun başına):
# il                   0
# bolge                0
# nufus                0
# dogurganlik_orani    0
# ortalama_yas         0
# dtype: int64
#
# Sayısal sütunların özeti:
#               nufus  dogurganlik_orani  ortalama_yas
# count  8.100000e+01          81.000000     81.000000
# mean   1.050471e+06           1.885679     33.141975
# std    1.902477e+06           0.537161      4.387478
# min    8.191000e+04           1.210000     22.600000
# 25%    2.991110e+05           1.530000     31.400000
# 50%    5.594050e+05           1.670000     33.800000
# 75%    1.116618e+06           1.990000     36.000000
# max    1.565592e+07           3.490000     41.500000

# %% [markdown]
# **📝 Yukarıdaki çıktıya bakarak Çalışma Kitapçığı'ndaki tabloyu doldur:**
# - Kaç **satır** (il) var?
# - Kaç **sütun** var?
# - Hangi sütunlarda **eksik (boş)** değer var? *(İpucu: "Eksik değer sayısı" satırına bak — hepsi 0 ise eksik yok.)*
#
# Son iki soru için (en kalabalık / en az nüfuslu il) bir sonraki hücreyi çalıştır 👇

# %%
# İlleri nüfusa göre büyükten küçüğe sıralayalım.
df_sirali = df.sort_values('nufus', ascending=False)

print('🏙️ En kalabalık il :', df_sirali.iloc[0]['il'],  '-', df_sirali.iloc[0]['nufus'], 'kişi')
print('🏡 En az nüfuslu il:', df_sirali.iloc[-1]['il'], '-', df_sirali.iloc[-1]['nufus'], 'kişi')
# Out:
# 🏙️ En kalabalık il : İstanbul - 15655924 kişi
# 🏡 En az nüfuslu il: Bayburt - 81910 kişi

# %% [markdown]
# 🧑‍🏫 **Cevap anahtarı (Bölüm 1):** 81 satır • 5 sütun • eksik değer **yok** • en kalabalık **İstanbul** (15.655.924) • en az **Bayburt** (81.910).

# %% [markdown]
# ---
# ## 2. Filtreleme Alıştırması
# ### 📝 Çalışma Kitapçığı — Gün 1, Bölüm 2
#
# **Filtreleme**, bir koşulu sağlayan satırları seçmektir — tıpkı A9'daki `if` gibi, ama tüm tabloya birden uygulanır.

# %%
# Bölgesi 'Doğu Anadolu' olan illeri seç.
# ✏️ İstersen başka bölge yaz: 'Marmara' · 'Ege' · 'Akdeniz' · 'İç Anadolu' · 'Karadeniz' · 'Doğu Anadolu' · 'Güneydoğu Anadolu'
dogu_anadolu = df[df['bolge'] == 'Doğu Anadolu']

print('Bu bölgede', len(dogu_anadolu), 'il var:')
print(list(dogu_anadolu['il']))
# Out:
# Bu bölgede 14 il var:
# ['Van', 'Malatya', 'Erzurum', 'Erzincan', 'Tunceli', 'Bingöl', 'Elazığ', 'Bitlis', 'Muş', 'Ağrı', 'Iğdır', 'Kars', 'Ardahan', 'Hakkari']

# %% [markdown]
# **📝 a)** Yukarıdaki listeden **en az 3 il** seçip Çalışma Kitapçığı'na yaz.
#
# Şimdi **b)** şıkkı: Malatya, bu bölgenin ortalamasının üstünde mi altında mı?

# %%
# Doğu Anadolu'nun ortalama nüfusunu hesapla ve Malatya ile karşılaştır.
ortalama = dogu_anadolu['nufus'].mean()
malatya  = df[df['il'] == 'Malatya']['nufus'].values[0]

print(f'Doğu Anadolu ortalama nüfusu: {ortalama:.0f} kişi')
print(f'Malatya nüfusu             : {malatya} kişi')

if malatya > ortalama:
    print('➡️  Malatya, ortalamanın ÜSTÜNDE')
else:
    print('➡️  Malatya, ortalamanın ALTINDA')
# Out:
# Doğu Anadolu ortalama nüfusu: 425041 kişi
# Malatya nüfusu             : 742725 kişi
# ➡️  Malatya, ortalamanın ÜSTÜNDE

# %% [markdown]
# 💡 **İsteğe bağlı:** Yukarıda `'nufus'` yerine `'dogurganlik_orani'` veya `'ortalama_yas'` yazıp tekrar çalıştırırsan o ölçüde karşılaştırırsın.
#
# 🧑‍🏫 **Cevap:** Malatya nüfusta ortalamanın **üstünde**.

# %% [markdown]
# ---
# ## 3. Kendi Grafiğini Oluştur
# ### 📝 Çalışma Kitapçığı — Gün 1, Bölüm 3
#
# Bir grafik, binlerce sayıyı tek bakışta anlatır. Aşağıda 3 hazır grafik var — hepsini çalıştır, sonra kendininkini yap.

# %% [markdown]
# **Çubuk grafik** — her bölgede kaç il var?

# %%
cubuk_grafigi(df, kategori_sutunu='bolge', baslik='Bölgelere Göre İl Sayısı')

# %% [markdown]
# 🔧 **Aynı fonksiyon, farklı soru.** `cubuk_grafigi` yalnızca *saymakla* kalmaz; ona `deger_sutunu` verirsen her grubun **ortalamasını** çizer. Tek satırı değiştirerek bambaşka bir soruyu yanıtlıyoruz:

# %%
cubuk_grafigi(df, kategori_sutunu='bolge', deger_sutunu='nufus',
              baslik='Bölgelere Göre ORTALAMA Nüfus')

# %% [markdown]
# 📊 **Nasıl yorumlanır?** Üstteki ilk grafik *“her bölgede kaç il var?”* diyordu; bu grafik *“o bölgelerdeki iller ne kadar kalabalık?”* diyor. İl **sayısı** çok olan bir bölge, **ortalama nüfusu** düşük olabilir (çok sayıda küçük il). İki grafik birbirinden farklı hikâye anlatır — doğru soruyu sormak, doğru grafiği seçmektir.

# %% [markdown]
# **Histogram** — illerin nüfusu nasıl dağılıyor?

# %%
histogram(df, sutun='nufus', baslik='İllerin Nüfus Dağılımı')

# %% [markdown]
# 🔧 **Başka bir sütunu incele.** Histogramda tek değiştirmen gereken şey `sutun=`. Nüfus yerine **ortalama yaş** dağılımına bakalım:

# %%
histogram(df, sutun='ortalama_yas', baslik='İllerin Ortalama Yaş Dağılımı')

# %% [markdown]
# 📊 **Nasıl yorumlanır?** Histogramda **tepe** noktası en sık görülen değeri gösterir. Dağılım **sağa kuyruklu** mu (birkaç il çok yaşlı/genç), yoksa **simetrik** mi? Nüfus dağılımı genelde *birkaç dev şehir* yüzünden sağa çok çarpıktır; yaş dağılımı çoğunlukla daha derli topludur. Karşılaştırın!

# %% [markdown]
# **Dağılım grafiği** — nüfus ile doğurganlık arasında ilişki var mı?

# %%
dagilim_grafigi(df, x_sutunu='nufus', y_sutunu='dogurganlik_orani',
                renk_sutunu='bolge', baslik='Nüfus ile Doğurganlık İlişkisi')
# Out:
# 📈 Dağılım grafiği çiziliyor: nufus - dogurganlik_orani

# %% [markdown]
# 🔧 **Renk ekle + tüm ilişkileri tek bakışta gör.** `renk_sutunu` ile noktaları bölgeye göre boyayabilir; `korelasyon_haritasi` ile de bütün sayısal sütunların ilişkisini tek karede görebilirsin:

# %%
dagilim_grafigi(df, x_sutunu='ortalama_yas', y_sutunu='dogurganlik_orani',
                renk_sutunu='bolge',
                baslik='Yaş – Doğurganlık (bölgeye göre renkli)')
korelasyon_haritasi(df, baslik='Sayısal Sütunlar Arası İlişki Haritası')
# Out:
# 📈 Dağılım grafiği çiziliyor: ortalama_yas - dogurganlik_orani

# %% [markdown]
# 📊 **Korelasyon haritası nasıl okunur?** Her kare iki sütunun birlikte hareketini gösterir: **+1** (koyu kırmızı) = *biri artarken diğeri de artar*; **−1** (koyu mavi) = *biri artarken diğeri azalır*; **0** = *ilişki yok*. Örneğin yaş ↑ iken doğurganlık ↓ ise bunu negatif (mavi) bir kare olarak görürsün. ⚠️ **Önemli:** korelasyon *neden-sonuç* demek değildir — iki şey birlikte değişiyor olabilir ama biri diğerinin **sebebi** olmayabilir.

# %% [markdown]
# ### ✏️ Şimdi SENİN grafiğin!
# Aşağıdaki hücre çalışır haldedir. **İki sütunu değiştirerek** kendi grafiğini yap.
# Sütunlar: `nufus` · `dogurganlik_orani` · `ortalama_yas` · `bolge`
#
# **📝** Hangi 2 sütunu seçtiğini, grafik türünü ve ne gözlemlediğini Çalışma Kitapçığı'na yaz.

# %%
# ✏️ x_sutunu ve y_sutunu'nu değiştir, sonra çalıştır.
dagilim_grafigi(df,
                x_sutunu='ortalama_yas',        # ✏️ bir sütun adı
                y_sutunu='dogurganlik_orani',   # ✏️ başka bir sütun adı
                renk_sutunu='bolge',
                baslik='Benim Grafiğim')

# 💡 Farklı grafik denemek istersen baştaki # işaretini kaldır:
# kutu_grafigi(df, kategori_sutunu='bolge', sayisal_sutun='nufus', baslik='Bölgelere Göre Nüfus')
# histogram(df, sutun='ortalama_yas', baslik='Ortalama Yaş Dağılımı')
# Out:
# 📈 Dağılım grafiği çiziliyor: ortalama_yas - dogurganlik_orani

# %% [markdown]
# 🧑‍🏫 **Örnek yorum:** "Ortalama yaş arttıkça doğurganlık azalıyor." Her grup farklı bir gözlem söyleyebilir — gözlem önemli, doğru/yanlış yok.

# %% [markdown]
# ---
# ## 4. Kendi Sorunu Sor
# ### 📝 Çalışma Kitapçığı — Gün 1, Bölüm 4
#
# Veriyle her türlü soruyu yanıtlayabilirsin. Örnek: **"Nüfusu 1 milyondan fazla kaç il var?"**

# %%
# Örnek: nüfusu 1.000.000'den büyük illeri seç ve say.
buyuk_iller = df[df['nufus'] > 1000000]
print('Nüfusu 1 milyondan fazla olan il sayısı:', len(buyuk_iller))
# Out:
# Nüfusu 1 milyondan fazla olan il sayısı: 24

# %% [markdown]
# ### ✏️ Şimdi SENİN sorun!
# Aşağıdaki eşiği değiştirerek farklı sorular sor. **📝** Sorunu, yöntemini ve cevabını Çalışma Kitapçığı'na yaz.

# %%
# ✏️ 500000 sayısını değiştir (örn. 2000000) ve çalıştır.
esik = 500000
sonuc = df[df['nufus'] > esik]
print(f'Nüfusu {esik} den fazla olan il sayısı:', len(sonuc))
print('Bu iller:', list(sonuc['il']))
# Out:
# Nüfusu 500000 den fazla olan il sayısı: 43
# Bu iller: ['İstanbul', 'Ankara', 'İzmir', 'Bursa', 'Antalya', 'Konya', 'Adana', 'Şanlıurfa', 'Gaziantep', 'Kocaeli', 'Mersin', 'Diyarbakır', 'Hatay', 'Manisa', 'Kayseri', 'Samsun', 'Balıkesir', 'Kahramanmaraş', 'Van', 'Aydın', 'Denizli', 'Sakarya', 'Tekirdağ', 'Muğla', 'Eskişehir', 'Mardin', 'Trabzon', 'Malatya', 'Erzurum', 'Ordu', 'Afyonkarahisar', 'Sivas', 'Adıyaman', 'Tokat', 'Batman', 'Çorum', 'Osmaniye', 'Zonguldak', 'Çanakkale', 'Elazığ', 'Ağrı', 'Şırnak', 'Kütahya']

# %% [markdown]
# 💡 **Başka soru fikirleri (isteğe bağlı):**
# ```python
# df[df['ortalama_yas'] > 40]['il']                                  # ortalama yaşı 40'tan büyük iller
# df.sort_values('dogurganlik_orani', ascending=False).head(5)        # doğurganlığı en yüksek 5 il
# ```

# %% [markdown]
# ---
# ## ✅ Gün Sonu — Ne Öğrendik?
#
# **Python temelleri:** değişken, sayı/metin, liste, sözlük, koşul (`if`), döngü (`for`), fonksiyon (`def`).
#
# **Veri analizi (Çalışma Kitapçığı'na yaz):**
#
# | Komut | Ne işe yarar? |
# |-------|---------------|
# | `veri_yukle('dosya.csv')` | CSV dosyasını tablo olarak yükler |
# | `veriyi_ozetle(df)` | Satır/sütun, eksik değer, özet |
# | `df[df['sutun'] > deger]` | Koşulu sağlayan satırları seçer (filtreleme) |
# | `df.sort_values('sutun')` | Veriyi bir sütuna göre sıralar |
# | `dagilim_grafigi(df, 'x', 'y')` | İki sütunun ilişkisini grafikle gösterir |
#
# ### 🚀 Yarın ne yapacağız?
# Bugün veride **örüntüler** gördük. Yarın bilgisayara bu örüntüleri **kendi kendine öğretip tahmin** yaptıracağız — buna **makine öğrenmesi** denir!
#
# Harikaydınız, yarın görüşürüz! 👋

# %% [markdown]
# ---
# ## 🆘 Bir hata mı aldın? Sık karşılaşılanlar
# - **`SyntaxError`** → Bir tırnak, parantez veya iki nokta `:` eksik olabilir. Satırı dikkatle kontrol et.
# - **`NameError: name '...' is not defined`** → Değişkeni yazmadan kullandın ya da yukarıdaki hücreyi çalıştırmadın.
# - **`FileNotFoundError`** → Drive bağlandı mı? **0. Hazırlık** hücresini çalıştırdın mı?
# - **`KeyError: 'Bolge'`** → Sütun adları küçük harf duyarlı; doğrusu `'bolge'`. `df.columns` ile bakabilirsin.
# - **Türkçe karakter** → Filtrelerken `'Doğu Anadolu'` yazımını birebir kopyala.
